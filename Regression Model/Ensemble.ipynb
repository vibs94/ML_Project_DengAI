# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import numpy as np
import pandas as pd
import seaborn as sns

from sklearn.dummy import DummyRegressor
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neural_network import MLPRegressor

from sklearn.metrics import mean_absolute_error

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

from sklearn.preprocessing import Imputer

# %matplotlib inline

# %%
pred1 = pd.read_csv('dengue_submission_004.csv')
print(pred1.head())
pred2 = pd.read_csv('submission_1.5.csv')
print(pred2.head())
pred3 = pd.read_csv('trend_submission_1.3.csv')
print(pred3.head())
gold = pd.read_csv('gold.csv')

pred = (pred1['total_cases']+pred2['total_cases'])/2.0

pred = pred.round().astype(int)
pred.head()
# Out:
#   city  year  weekofyear  total_cases
# 0   sj  2008          18           10
# 1   sj  2008          19           10
# 2   sj  2008          20           10
# 3   sj  2008          21           10
# 4   sj  2008          22           10
#   city  year  weekofyear  total_cases
# 0   sj  2008          18           10
# 1   sj  2008          19           10
# 2   sj  2008          20           10
# 3   sj  2008          21           10
# 4   sj  2008          22           10
#   city  year  weekofyear  total_cases
# 0   sj  2008          18            5
# 1   sj  2008          19            6
# 2   sj  2008          20            8
# 3   sj  2008          21            9
# 4   sj  2008          22            9
# 0    10
# 1    10
# 2    10
# 3    10
# 4    10
# Name: total_cases, dtype: int32

# %%
plt.figure(figsize=(12,7))
plt.plot(pred1.total_cases,label="Regression Model 2")
plt.plot(pred2.total_cases,label="Regression Model 1")
plt.plot(pred3.total_cases,label="Time Series Model")
plt.plot(pred,label="Ensemble Model")
plt.plot(gold,label="Gold")
plt.legend()
plt.show()

# %%
submission = pd.read_csv("submission_format.csv")
submission['total_cases'] = pred
print(submission.head())
submission.to_csv("submission_2.0.csv",index=False)
# Out:
#   city  year  weekofyear  total_cases
# 0   sj  2008          18           10
# 1   sj  2008          19           10
# 2   sj  2008          20           10
# 3   sj  2008          21           10
# 4   sj  2008          22           10
